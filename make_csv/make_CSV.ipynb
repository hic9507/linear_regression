# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !pip install yfinance
import yfinance as yf

print(tf.__version__)
# Out:
# ...
# 2.9.1

# %% [markdown]
# 야후 파이낸스 주식 데이터 추출

# %%
# 애플
apple_df=yf.download("AAPL",start="2022-11-01",end="2022-11-15")
print(apple_df)

# MS
microsoft_df=yf.download("MSFT",start="2022-11-01",end="2022-11-15")
print(microsoft_df)

# 구글
google_df=yf.download("GOOG",start="2022-11-01",end="2022-11-15")
print(google_df)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-11-01  155.080002  155.449997  149.130005  150.649994  149.564514
# 2022-11-02  148.949997  152.169998  145.000000  145.029999  143.985001
# 2022-11-03  142.059998  142.800003  138.750000  138.880005  137.879318
# 2022-11-04  142.089996  142.669998  134.380005  138.380005  137.610825
# 2022-11-07  137.110001  139.149994  135.669998  138.919998  138.147797
# 2022-11-08  140.410004  141.429993  137.490005  139.500000  138.724594
# 2022-11-09  138.500000  138.550003  134.589996  134.869995  134.120331
# 2022-11-10  141.240005  146.869995  139.500000  146.869995  146.053635
# 2022-11-11  145.820007  150.009995  144.369995  149.699997  148.867905
# 2022-11-14  148.970001  150.279999  147.429993  148.279999  147.455795
#
#                Volume
# Date
# 2022-11-01   80379300
# 2022-11-02   93604600
# 2022-11-03   97918500
# ...

# %% [markdown]
# pandas to CSV

# %%
apple_df.to_csv("sample_data/apple.csv")
microsoft_df.to_csv("sample_data/microsoft.csv")
google_df.to_csv("sample_data/google.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# C:\Users\user\AppData\Local\Temp\ipykernel_13628\665465569.py in <module>
# ----> 1 apple_df.to_csv("sample_data/apple.csv")
#       2 microsoft_df.to_csv("sample_data/microsoft.csv")
#       3 google_df.to_csv("sample_data/google.csv")
#
# C:\Users\user\anaconda3\envs\bigdata\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ...

# %% [markdown]
# csv 파일 생성

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# !pip install yfinance
import yfinance as yf
from datetime import datetime, timedelta
import random

def createCSVdata(startDate, endDate, dataLength, dataNumber, fileName):
    start = datetime.strptime(startDate, '%Y-%m-%d')
    end = datetime.strptime(endDate, '%Y-%m-%d')

    # 전체 기간을 일자 리스트로 변환
    date_generated = [start + timedelta(days=x) for x in range(0, (end-start).days)]

    # 데이터 프레임 생성
    data = {'Date': [], 'Value': []}

    # dataNumber만큼 데이터 생성
    for _ in range(dataNumber):
        # 시작일자부터 dataLength만큼의 연속 일자 선택
        random_start = random.choice(date_generated[:-dataLength])
        date_range = [random_start + timedelta(days=x) for x in range(dataLength)]

        # 해당 일자에 대한 무작위 값 생성
        values = np.random.random(dataLength)

        # 데이터 프레임에 추가
        for date, value in zip(date_range, values):
            data['Date'].append(date)
            data['Value'].append(value)

    # 데이터 프레임 생성 및 파일로 저장
    df = pd.DataFrame(data)
    df.to_csv(fileName, index=False)
    print(f'File saved as {fileName}')

# 함수 사용 예시
createCSVdata('2022-11-01', '2022-11-15', 5, 10, './sample_data.csv')
# Out:
# ...
# File saved as ./sample_data.csv

# %% [markdown]
# csv 파일 출력

# %%
pad = pd.read_csv("./sample_data.csv")
pad
# Out:
#           Date     Value
# 0   2022-11-09  0.809653
# 1   2022-11-10  0.967570
# 2   2022-11-11  0.256504
# 3   2022-11-12  0.721491
# 4   2022-11-13  0.290026
# 5   2022-11-09  0.347277
# 6   2022-11-10  0.735972
# 7   2022-11-11  0.999589
# 8   2022-11-12  0.225732
# 9   2022-11-13  0.941710
# 10  2022-11-02  0.862209
# 11  2022-11-03  0.230488
# 12  2022-11-04  0.834659
# 13  2022-11-05  0.004340
# 14  2022-11-06  0.014549
# 15  2022-11-03  0.866742
# 16  2022-11-04  0.515567
# 17  2022-11-05  0.408778
# 18  2022-11-06  0.870582
# 19  2022-11-07  0.715411
# 20  2022-11-08  0.787601
# 21  2022-11-09  0.386617
# 22  2022-11-10  0.631531
# 23  2022-11-11  0.362897
# 24  2022-11-12  0.579716
# 25  2022-11-01  0.137866
# 26  2022-11-02  0.754783
# 27  2022-11-03  0.645770
# 28  2022-11-04  0.283651
# 29  2022-11-05  0.757174
# 30  2022-11-04  0.648338
# 31  2022-11-05  0.677790
# 32  2022-11-06  0.563427
# 33  2022-11-07  0.048226
# 34  2022-11-08  0.279453
# 35  2022-11-07  0.062448
# ...
